# %% [markdown]
# # ViTHSD - Dataset A - FlanT5 (Fine-tuning)
#
# **Model 2/3 for Dataset A**
#
# - **Model**: google/flan-t5-base
# - **Dataset**: A (Original ViTHSD - content + labels only)
# - **Task**: Multi-Label Classification (11 labels)
# - **Technique**: Full Fine-tuning
#
# ###  Label Constraint
# - Each category can only have **ONE level**: offensive OR hate (not both)

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# Install required libraries
# !pip uninstall -y protobuf
# !pip install -q protobuf==3.20.0
# !pip install -q transformers datasets accelerate sentencepiece
# !pip install -q scikit-learn pandas numpy tqdm openpyxl

# Suppress warnings
import os
import warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['GRPC_VERBOSITY'] = 'ERROR'
warnings.filterwarnings('ignore')

print(" Dependencies installed!")
# Out:
# Found existing installation: protobuf 6.33.0
# Uninstalling protobuf-6.33.0:
#   Successfully uninstalled protobuf-6.33.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 4.7 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# google-cloud-translate 3.12.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-secret-manager 2.25.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-vision 3.11.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-monitoring 2.28.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-videointelligence 2.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-api-core 2.28.1 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5, but you have protobuf 3.20.0 which is incompatible.
# a2a-sdk 0.3.10 requires protobuf>=5.29.5, but you have protobuf 3.20.0 which is incompatible.
# ray 2.51.1 requires click!=8.3.0,>=7.0, but you have click 8.3.0 which is incompatible.
# ray 2.51.1 requires protobuf>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-bigtable 2.34.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-discoveryengine 0.13.12 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-aiplatform 1.125.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-speech 2.34.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-logging 3.12.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-trace 1.17.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-appengine-logging 1.7.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-audit-log 0.4.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-functions 1.20.4 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-resource-manager 1.14.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# google-cloud-dataproc 5.21.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.0 which is incompatible.
# googleapis-common-protos 1.70.0 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 46.0.3 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.3.0 which is incompatible.
# google-cloud-datastore 2.21.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-iam 2.19.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-language 2.17.2 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-bigquery-connection 1.18.3 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# grpc-google-iam-v1 0.14.2 requires protobuf!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-spanner 3.56.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# google-cloud-firestore 2.21.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0dev,>=3.20.2, but you have protobuf 3.20.0 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 100.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# ✅ Dependencies installed!

# %%
# GPU Auto-Detection & Optimization
import torch
import os

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
  num_gpus = torch.cuda.device_count()
  print(f"\n{'='*70}")
  print(f" DETECTED: {num_gpus} GPU(s)")
  print(f"{'='*70}")
  
  for i in range(num_gpus):
    gpu_name = torch.cuda.get_device_name(i)
    print(f"GPU {i}: {gpu_name}")
  
  # Auto-configure based on number of GPUs
  if num_gpus == 1:
    # Single GPU (P100)
    print(f"\n{'='*70}")
    print(" SINGLE GPU MODE (P100 Optimized)")
    print(f"{'='*70}")
    
    os.environ['CUDA_VISIBLE_DEVICES'] = '0'
    
    BATCH_SIZE_FLANT5 = 8 # P100 (16GB) - FlanT5 nhẹ hơn Qwen
    
    GPU_CONFIG = {
      'num_gpus': 1,
      'device': 'cuda:0',
      'batch_sizes': {
        'flant5': BATCH_SIZE_FLANT5
      },
      'gradient_accumulation_steps': 1
    }
    
  elif num_gpus >= 2:
    # Multi-GPU (T4 x2)
    print(f"\n{'='*70}")
    print(" MULTI-GPU MODE (T4 x2 Maximum Performance)")
    print(f"{'='*70}")
    
    BATCH_SIZE_FLANT5 = 16 # T4 x2 (32GB)
    
    GPU_CONFIG = {
      'num_gpus': num_gpus,
      'device': 'cuda',
      'batch_sizes': {
        'flant5': BATCH_SIZE_FLANT5
      },
      'gradient_accumulation_steps': 1
    }
  
  print(f"\n Configured Batch Size:")
  print(f" FlanT5: {GPU_CONFIG['batch_sizes']['flant5']}")
  print(f"\n{'='*70}\n")
  
else:
  print(" No GPU detected! This notebook requires GPU.")
  GPU_CONFIG = None
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: True
#
# ======================================================================
# 🎮 DETECTED: 2 GPU(s)
# ======================================================================
# GPU 0: Tesla T4
# GPU 1: Tesla T4
#
# ======================================================================
# ⚡ MULTI-GPU MODE (T4 x2 Maximum Performance)
# ======================================================================
#
# 📊 Configured Batch Size:
#    FlanT5: 16
#
# ======================================================================

# %% [markdown]
# ## Step 2: Import and Setup Paths

# %%
import sys
import os

# Copy files ra working directory
# !cp -r /kaggle/input/vithsd-experiment/* /kaggle/working/

os.chdir("/kaggle/working")
sys.path.insert(0, "/kaggle/working")

print(" Files copied to working directory")
# Out:
# 📁 Files copied to working directory

# %%
# Import modules
from config import FINAL_LABELS, DATA_DIR, OUTPUT_DIR
from data_preparation import load_dataset_A
from evaluation import Evaluator
from models import create_model

print(" All modules imported!")
print(f" Labels: {len(FINAL_LABELS)}")
# Out:
# ✅ All modules imported!
# 📊 Labels: 11

# %% [markdown]
# ## Step 3: Load Dataset A

# %%
# Load Dataset A
train_texts, train_labels = load_dataset_A('train')
test_texts, test_labels = load_dataset_A('test')

print(f" Dataset A:")
print(f" Train: {len(train_texts)} samples")
print(f" Test: {len(test_texts)} samples")
# Out:
# [ViHSDLoader] Loaded 7000 samples from train
# [ViHSDLoader] Loaded 1800 samples from test
# 📊 Dataset A:
#    Train: 7000 samples
#    Test: 1800 samples

# %% [markdown]
# ## Step 4: Train FlanT5

# %%
# Initialize
evaluator = Evaluator()

# FlanT5 - Dataset A
print("="*70)
print(" FLANT5 - DATASET A")
print("="*70)

model_flant5 = create_model(
  "flant5", 
  dataset_type="A",
  batch_size=GPU_CONFIG['batch_sizes']['flant5'], # Auto-adjusted
  num_epochs=3,
  learning_rate=3e-5
)

# Train
model_flant5.train(train_texts, train_labels)

# Predict
pred_flant5, _ = model_flant5.predict(test_texts)

# Evaluate
result = evaluator.evaluate(test_labels, pred_flant5, "FlanT5", "A")
evaluator.print_result(result)
# Out:
# ======================================================================
# 🚀 FLANT5 - DATASET A
# ======================================================================
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765782032.676299      20 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765782032.789141      20 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# [FlanT5_MultiLabel] Training...
#   Device: cuda
#   Original samples: 7000
#   Mode: Standard (Dataset A)
#   [Oversampling] Added 540 samples for minority labels
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
#   Tokenizing...
#   Training for 3 epochs...
# Epoch 1/3:   0%|          | 0/472 [00:00<?, ?it/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Epoch 1/3: 100%|██████████| 472/472 [08:29<00:00,  1.08s/it, loss=0.1010]
#   Epoch 1: avg_loss = 1.9593
# Epoch 2/3: 100%|██████████| 472/472 [08:35<00:00,  1.09s/it, loss=0.0348]
#   Epoch 2: avg_loss = 0.1026
# Epoch 3/3: 100%|██████████| 472/472 [08:36<00:00,  1.09s/it, loss=0.1063]
#   Epoch 3: avg_loss = 0.0980
#   ✓ Training completed
# Predicting:   0%|          | 0/113 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   1%|          | 1/113 [00:00<01:09,  1.60it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   2%|▏         | 2/113 [00:01<01:22,  1.35it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   3%|▎         | 3/113 [00:01<01:10,  1.57it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   4%|▎         | 4/113 [00:02<01:03,  1.71it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   4%|▍         | 5/113 [00:02<00:58,  1.83it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   5%|▌         | 6/113 [00:03<00:56,  1.89it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   6%|▌         | 7/113 [00:03<00:55,  1.91it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   7%|▋         | 8/113 [00:04<00:53,  1.97it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   8%|▊         | 9/113 [00:04<00:50,  2.04it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:   9%|▉         | 10/113 [00:05<00:49,  2.10it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  10%|▉         | 11/113 [00:05<00:49,  2.06it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  11%|█         | 12/113 [00:06<00:49,  2.05it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  12%|█▏        | 13/113 [00:06<00:49,  2.04it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  12%|█▏        | 14/113 [00:07<00:47,  2.10it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  13%|█▎        | 15/113 [00:07<00:40,  2.45it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  14%|█▍        | 16/113 [00:07<00:39,  2.43it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  15%|█▌        | 17/113 [00:08<00:39,  2.41it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  16%|█▌        | 18/113 [00:08<00:40,  2.36it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  17%|█▋        | 19/113 [00:09<00:41,  2.25it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  18%|█▊        | 20/113 [00:09<00:42,  2.17it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  19%|█▊        | 21/113 [00:10<00:36,  2.51it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  19%|█▉        | 22/113 [00:10<00:39,  2.32it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  20%|██        | 23/113 [00:11<00:40,  2.22it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  21%|██        | 24/113 [00:11<00:40,  2.20it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  22%|██▏       | 25/113 [00:12<00:41,  2.13it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  23%|██▎       | 26/113 [00:12<00:46,  1.86it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  24%|██▍       | 27/113 [00:13<00:45,  1.90it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  25%|██▍       | 28/113 [00:13<00:42,  1.99it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  26%|██▌       | 29/113 [00:14<00:42,  1.99it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  27%|██▋       | 30/113 [00:14<00:49,  1.67it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  27%|██▋       | 31/113 [00:15<00:46,  1.76it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  28%|██▊       | 32/113 [00:15<00:43,  1.86it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  29%|██▉       | 33/113 [00:16<00:42,  1.90it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  30%|███       | 34/113 [00:16<00:40,  1.94it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  31%|███       | 35/113 [00:17<00:39,  2.00it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  32%|███▏      | 36/113 [00:17<00:38,  1.99it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  33%|███▎      | 37/113 [00:18<00:38,  2.00it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  34%|███▎      | 38/113 [00:19<00:44,  1.67it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  35%|███▍      | 39/113 [00:19<00:39,  1.88it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  35%|███▌      | 40/113 [00:20<00:37,  1.96it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  36%|███▋      | 41/113 [00:20<00:36,  1.97it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  37%|███▋      | 42/113 [00:20<00:34,  2.09it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  38%|███▊      | 43/113 [00:21<00:32,  2.16it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  39%|███▉      | 44/113 [00:21<00:32,  2.15it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  40%|███▉      | 45/113 [00:22<00:32,  2.12it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  41%|████      | 46/113 [00:22<00:32,  2.07it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  42%|████▏     | 47/113 [00:23<00:32,  2.04it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  42%|████▏     | 48/113 [00:23<00:32,  2.02it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  43%|████▎     | 49/113 [00:24<00:30,  2.12it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  44%|████▍     | 50/113 [00:24<00:29,  2.17it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  45%|████▌     | 51/113 [00:25<00:29,  2.09it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  46%|████▌     | 52/113 [00:25<00:29,  2.05it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  47%|████▋     | 53/113 [00:26<00:29,  2.03it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  48%|████▊     | 54/113 [00:26<00:29,  2.02it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  49%|████▊     | 55/113 [00:27<00:27,  2.09it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  50%|████▉     | 56/113 [00:27<00:27,  2.06it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  50%|█████     | 57/113 [00:28<00:32,  1.71it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  51%|█████▏    | 58/113 [00:28<00:29,  1.84it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  52%|█████▏    | 59/113 [00:29<00:24,  2.24it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  53%|█████▎    | 60/113 [00:29<00:24,  2.16it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  54%|█████▍    | 61/113 [00:30<00:24,  2.14it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  55%|█████▍    | 62/113 [00:30<00:24,  2.10it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  56%|█████▌    | 63/113 [00:31<00:24,  2.06it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  57%|█████▋    | 64/113 [00:31<00:23,  2.10it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  58%|█████▊    | 65/113 [00:32<00:23,  2.06it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  58%|█████▊    | 66/113 [00:32<00:22,  2.05it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  59%|█████▉    | 67/113 [00:33<00:22,  2.02it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  60%|██████    | 68/113 [00:33<00:21,  2.09it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  61%|██████    | 69/113 [00:34<00:21,  2.05it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  62%|██████▏   | 70/113 [00:34<00:20,  2.08it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  63%|██████▎   | 71/113 [00:35<00:20,  2.07it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  64%|██████▎   | 72/113 [00:35<00:19,  2.09it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  65%|██████▍   | 73/113 [00:36<00:19,  2.06it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  65%|██████▌   | 74/113 [00:36<00:18,  2.10it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  66%|██████▋   | 75/113 [00:36<00:18,  2.06it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  67%|██████▋   | 76/113 [00:37<00:18,  2.05it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  68%|██████▊   | 77/113 [00:37<00:16,  2.25it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  69%|██████▉   | 78/113 [00:38<00:16,  2.17it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  70%|██████▉   | 79/113 [00:38<00:15,  2.19it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  71%|███████   | 80/113 [00:39<00:18,  1.75it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  72%|███████▏  | 81/113 [00:40<00:17,  1.82it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  73%|███████▎  | 82/113 [00:40<00:15,  1.97it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  73%|███████▎  | 83/113 [00:40<00:14,  2.04it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  74%|███████▍  | 84/113 [00:41<00:14,  2.02it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  75%|███████▌  | 85/113 [00:41<00:13,  2.00it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  76%|███████▌  | 86/113 [00:42<00:13,  2.01it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  77%|███████▋  | 87/113 [00:42<00:12,  2.01it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  78%|███████▊  | 88/113 [00:43<00:12,  2.01it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  79%|███████▉  | 89/113 [00:43<00:12,  2.00it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  80%|███████▉  | 90/113 [00:44<00:11,  1.97it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  81%|████████  | 91/113 [00:45<00:13,  1.66it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  81%|████████▏ | 92/113 [00:46<00:13,  1.50it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  82%|████████▏ | 93/113 [00:46<00:12,  1.65it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  83%|████████▎ | 94/113 [00:47<00:10,  1.76it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  84%|████████▍ | 95/113 [00:47<00:11,  1.55it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  85%|████████▍ | 96/113 [00:48<00:10,  1.67it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  86%|████████▌ | 97/113 [00:48<00:09,  1.76it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  87%|████████▋ | 98/113 [00:49<00:07,  2.14it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  88%|████████▊ | 99/113 [00:49<00:06,  2.07it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  88%|████████▊ | 100/113 [00:50<00:06,  2.04it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  89%|████████▉ | 101/113 [00:50<00:05,  2.02it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  90%|█████████ | 102/113 [00:51<00:05,  2.01it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  91%|█████████ | 103/113 [00:51<00:05,  2.00it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  92%|█████████▏| 104/113 [00:52<00:04,  1.98it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  93%|█████████▎| 105/113 [00:52<00:03,  2.05it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  94%|█████████▍| 106/113 [00:53<00:03,  2.03it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  95%|█████████▍| 107/113 [00:53<00:02,  2.02it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  96%|█████████▌| 108/113 [00:54<00:02,  2.01it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  96%|█████████▋| 109/113 [00:54<00:01,  2.01it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  97%|█████████▋| 110/113 [00:54<00:01,  2.39it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  98%|█████████▊| 111/113 [00:55<00:00,  2.26it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting:  99%|█████████▉| 112/113 [00:55<00:00,  2.17it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Predicting: 100%|██████████| 113/113 [00:56<00:00,  2.01it/s]
# ======================================================================
# 📊 FlanT5 on Dataset A (Multi-Label)
# ======================================================================
#   Subset Accuracy (Exact Match): 0.4622
#   Hamming Loss:                  0.1174
#   F1 Samples:                    0.5074
#   F1 Macro:                      0.1311
#   F1 Micro:                      0.4684
#   Precision (Samples):           0.5033
#   Recall (Samples):              0.5210
#
#   F1 per Label:
#     normal                   : 0.6732
#     individuals#hate         : 0.3583
#     groups#hate              : 0.3493
#     race#hate                : 0.0312
#     politics#hate            : 0.0299

# %% [markdown]
# ## Step 5: Save Results

# %%
from pathlib import Path
import json

# Create output directory
output_dir = Path("/kaggle/working/outputs_datasetA_flant5")
output_dir.mkdir(exist_ok=True)

# Save results
evaluator.save_results(output_dir)

# Save report
report = evaluator.generate_report()
with open(output_dir / "experiment_report_flant5.txt", 'w') as f:
  f.write(report)

print(f"\n Results saved to {output_dir}")
# Out:
# ✓ Saved results to /kaggle/working/outputs_datasetA_flant5/experiment_results.json
# ✓ Saved comparison matrix to /kaggle/working/outputs_datasetA_flant5/comparison_matrix.csv
# ✓ Saved full comparison to /kaggle/working/outputs_datasetA_flant5/full_comparison.csv
#
# ✅ Results saved to /kaggle/working/outputs_datasetA_flant5

# %%
# Save trained model
import torch
from pathlib import Path

models_dir = Path("/kaggle/working/outputs_datasetA_flant5/models")
models_dir.mkdir(exist_ok=True)

# Save FlanT5 weights
try:
  torch.save(model_flant5.model.state_dict(), models_dir / "flant5_model.pt")
  print(" Saved: flant5_model.pt")
except Exception as e:
  print(f" Unable to save FlanT5 model: {e}")

print(f"\n Models saved to: {models_dir}")
# Out:
# ✅ Saved: flant5_model.pt
#
# 📁 Models saved to: /kaggle/working/outputs_datasetA_flant5/models

# %%
# Create a ZIP file for download
import shutil
from pathlib import Path

zip_path = "/kaggle/working/vithsd_datasetA_flant5_results"
shutil.make_archive(zip_path, 'zip', "/kaggle/working/outputs_datasetA_flant5")

print(f" Created: {zip_path}.zip")
print(f" Zip size: {Path(zip_path + '.zip').stat().st_size / (1024*1024):.2f} MB")
# Out:
# ✅ Created: /kaggle/working/vithsd_datasetA_flant5_results.zip
# 📦 Zip size: 876.42 MB

# %% [markdown]
# ## Step 6: Per-Label Analysis

# %%
# Per-label F1 Analysis
print("\n" + "="*100)
print("📈 DATASET A - PER-LABEL F1 SCORES (FlanT5)")
print("="*100)

for r in evaluator.results:
  print(f"\n{r['model']}:")
  print("-" * 80)
  f1_per_label = r['f1_per_label']
  sorted_labels = sorted(f1_per_label.items(), key=lambda x: x[1], reverse=True)
  for label, f1 in sorted_labels:
    bar_length = int(f1 * 40)
    bar = "█" * bar_length + "░" * (40 - bar_length)
    print(f" {label:25s} | {bar} | {f1:.4f}")
# Out:
# ====================================================================================================
# 📈 DATASET A - PER-LABEL F1 SCORES (FlanT5)
# ====================================================================================================
#
# FlanT5:
# --------------------------------------------------------------------------------
#   normal                    | ██████████████████████████░░░░░░░░░░░░░░ | 0.6732
#   individuals#hate          | ██████████████░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.3583
#   groups#hate               | █████████████░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.3493
#   race#hate                 | █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0312
#   politics#hate             | █░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0299
#   individuals#offensive     | ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0000
#   groups#offensive          | ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0000
#   religion#offensive        | ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0000
#   religion#hate             | ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0000
#   race#offensive            | ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0000
#   politics#offensive        | ░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░░ | 0.0000

# %% [markdown]
# ## 🎉 Done - FlanT5 on Dataset A!
#
# **Model executed on Dataset A (Original):**
# - FlanT5 (google/flan-t5-base)
#
# Results: `/kaggle/working/outputs_datasetA_flant5/`
